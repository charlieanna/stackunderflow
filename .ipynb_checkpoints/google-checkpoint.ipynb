# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types
import os
# Instantiates a client
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/Users/charlieana/Downloads/SocialMediaMining/My_Project-990cf6741e7f.json"
client = language.LanguageServiceClient()

def classify_text(text):
    """Classifies content categories of the provided text."""
    client = language.LanguageServiceClient()

    document = types.Document(
        content=text.encode('utf-8'),
        type=enums.Document.Type.PLAIN_TEXT)

    entities = client.analyze_entities(document).entities

    # entity types from enums.Entity.Type
    entity_type = ('UNKNOWN', 'PERSON', 'LOCATION', 'ORGANIZATION',
                   'EVENT', 'WORK_OF_ART', 'CONSUMER_GOOD', 'OTHER')

    for entity in entities:
        print('=' * 20)
        print(u'{:<16}: {}'.format('name', entity.name))
        print(u'{:<16}: {}'.format('type', entity_type[entity.type]))
        print(u'{:<16}: {}'.format('metadata', entity.metadata))
        print(u'{:<16}: {}'.format('salience', entity.salience))
        print(u'{:<16}: {}'.format('wikipedia_url',
              entity.metadata.get('wikipedia_url', '-')))
text = """
4
down vote
A pattern emerges when several people (or teams) arrives at similar or identical solutions. A lot of people still use singletons in their original form or using factory templates (good discussion in Alexandrescu's Modern C++ Design). Concurrency and difficulty in managing the lifetime of the object are the main obstacles, with the former easily managed as you suggest.

Like all choices, Singleton has its fair share of ups and downs. I think they can be used in moderation, especially for objects that survive the application life span. The fact that they resemble (and probably are) globals have presumably set off the purists."""        
classify_text(text)
# Out:
# ====================
# name            : pattern
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f4212b0>
# salience        : 0.1969534307718277
# wikipedia_url   : -
# ====================
# name            : people
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50f670>
# salience        : 0.15906204283237457
# wikipedia_url   : -
# ====================
# name            : teams
# type            : ORGANIZATION
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50f850>
# salience        : 0.1406162530183792
# wikipedia_url   : -
# ====================
# name            : singletons
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50f9e0>
# salience        : 0.07585489004850388
# wikipedia_url   : -
# ====================
# name            : solutions
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50fa80>
# salience        : 0.05476531758904457
# wikipedia_url   : -
# ====================
# name            : objects
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50fcb0>
# salience        : 0.035872459411621094
# wikipedia_url   : -
# ====================
# name            : people
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50fda0>
# salience        : 0.030147166922688484
# wikipedia_url   : -
# ====================
# name            : form
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50fdf0>
# salience        : 0.026508882641792297
# wikipedia_url   : -
# ====================
# name            : obstacles
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50fe90>
# salience        : 0.022781401872634888
# wikipedia_url   : -
# ====================
# name            : lifetime
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50ff30>
# salience        : 0.020543094724416733
# wikipedia_url   : -
# ====================
# name            : object
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f50f7b0>
# salience        : 0.020543094724416733
# wikipedia_url   : -
# ====================
# name            : lot
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539080>
# salience        : 0.020013095811009407
# wikipedia_url   : -
# ====================
# name            : factory templates
# type            : CONSUMER_GOOD
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539120>
# salience        : 0.018146542832255363
# wikipedia_url   : -
# ====================
# name            : difficulty
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539170>
# salience        : 0.018056688830256462
# wikipedia_url   : -
# ====================
# name            : discussion
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539210>
# salience        : 0.01792573556303978
# wikipedia_url   : -
# ====================
# name            : Concurrency
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f5392b0>
# salience        : 0.01761990413069725
# wikipedia_url   : -
# ====================
# name            : choices
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539350>
# salience        : 0.016515055671334267
# wikipedia_url   : -
# ====================
# name            : moderation
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f5393f0>
# salience        : 0.014138157479465008
# wikipedia_url   : -
# ====================
# name            : fact
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539490>
# salience        : 0.013764910399913788
# wikipedia_url   : -
# ====================
# name            : Singleton
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539580>
# salience        : 0.013052918016910553
# wikipedia_url   : https://en.wikipedia.org/wiki/Singleton_pattern
# ====================
# name            : application life span
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f5395d0>
# salience        : 0.012423671782016754
# wikipedia_url   : -
# ====================
# name            : Modern C++ Design
# type            : WORK_OF_ART
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539670>
# salience        : 0.010615294799208641
# wikipedia_url   : https://en.wikipedia.org/wiki/Modern_C++_Design
# ====================
# name            : Alexandrescu
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539710>
# salience        : 0.010615294799208641
# wikipedia_url   : https://en.wikipedia.org/wiki/Andrei_Alexandrescu
# ====================
# name            : purists
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539850>
# salience        : 0.00868335273116827
# wikipedia_url   : -
# ====================
# name            : globals
# type            : PERSON
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539940>
# salience        : 0.00836921762675047
# wikipedia_url   : -
# ====================
# name            : downs
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539990>
# salience        : 0.0054707094095647335
# wikipedia_url   : -
# ====================
# name            : ups
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f5399e0>
# salience        : 0.0054707094095647335
# wikipedia_url   : -
# ====================
# name            : share
# type            : OTHER
# metadata        : <google.protobuf.pyext._message.ScalarMapContainer object at 0x10f539a30>
# salience        : 0.0054707094095647335
# wikipedia_url   : -
